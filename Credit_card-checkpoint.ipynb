# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, confusion_matrix, recall_score, f1_score
import sklearn.metrics as metrics

# %%
data = pd.read_csv('creditcard.csv')

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.size
# Out:
# 8829017

# %%
data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %% [markdown]
# ## Data Information

# %%
#data information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# ### Checking the no. of missing values in each column

# %%
#checking the no. of missing values in each column
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# ### Distribution of legit transctions & fraudulant transcations

# %%
data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# ##### This data is highly unbalanced
# ##### 0 ---> Normal Transaction
# ##### 1 ---> fraudulent transaction

# %% [markdown]
# ### Separating the data for analysis

# %%
legit = data[data.Class == 0]
fraud = data[data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %% [markdown]
# ### Statistical measures of the data

# %%
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %% [markdown]
# ## Visualization

# %%
count_classes = pd.Series(data['Class']).value_counts(sort =True)
cr=['blue','green']
count_classes.plot(kind = 'bar' ,rot =0, color = cr)
plt.title("Transaction class Distribution")
labels = ['Normal' ,'Fraud']
plt.xticks(range(2),labels)
plt.xlabel("Class")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
labels = ['Normal', 'Fraud']
sizes = [len(legit), len(fraud)]
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax.axis('equal')  
plt.show()

# %%
# We Will check Do fraudulent transactions occur more often during certain time frame ? Let us find out with a visual representation.
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Time of transaction vs Amount by class')
ax1.scatter(fraud.Time, fraud.Amount)
ax1.set_title('Fraud')
ax2.scatter(legit.Time, legit.Amount)
ax2.set_title('Normal')
plt.xlabel('Time (in Seconds)')
plt.ylabel('Amount')
plt.show()

# %%
#campare the values for both transaction
data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# #### Under-Sampling
# ##### Build a sample dataset containg similar distribution of normal transction and fraudlent Transactions
# ##### Number of fraudulent  transactions = 492

# %%
legit_sample =legit.sample(n=492)

# %%
#concatenting two dataframes
new_data = pd.concat([legit_sample, fraud], axis=0)

# %%
new_data.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 229347  145887.0  1.748902 -0.989431  0.551572  1.539388 -0.982681  1.699766
# 253772  156414.0 -1.244621 -0.076079 -1.178757  0.266465  4.208991  3.038824
# 65622    51674.0 -1.928219  2.462479  0.456899 -0.355525  0.268436  0.654057
# 71288    54241.0  1.215496 -0.015518 -1.205686 -0.043102  2.165224  3.335896
# 241558  151077.0  0.109500  1.079375 -0.206070 -0.449092  0.762131 -0.999716
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 229347 -1.585061  0.665052  2.237661  ...  0.153117  0.830189  0.041446
# 253772  0.135835  0.996677 -0.883871  ... -0.119922 -0.718561  0.015753
# 65622  -0.986151 -5.754627  0.163993  ...  4.985826 -2.578097  0.633907
# 71288  -0.347725  0.786590 -0.143654  ... -0.208616 -0.837018 -0.016563
# 241558  1.002493 -0.140685 -0.150528  ... -0.301485 -0.689990  0.150264
#
# ...

# %%
new_data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new_data['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %% [markdown]
# ### Visualization of Balanced Dataset

# %%
count_classes = pd.Series(new_data['Class']).value_counts(sort =True)
cr=['blue','green']
count_classes.plot(kind = 'bar' ,rot =0, color = cr)
plt.title("Transaction class Distribution")
labels = ['Normal' ,'Fraud']
plt.xticks(range(2),labels)
plt.xlabel("Class")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#balance dataset
labels = ['Normal', 'Fraud']
sizes = [len(legit_sample), len(fraud)]
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax.axis('equal')  
plt.show()

# %%
new_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      96790.512195  0.018178  0.014082  0.037364  0.024600  0.045931
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.094094 -0.035116 -0.007651 -0.013527  ... -0.009460  0.005221
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23      V24       V25       V26       V27       V28  \
# Class
# 0      0.016452  0.058158  0.00596  0.004059  0.014412  0.009831  0.010278
# 1      0.014049 -0.040308 -0.10513  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       79.849004
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# ### Splitting the data into features & Targets

# %%
X = new_data.drop(columns='Class', axis=1)
Y = new_data['Class']

# %%
X
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 229347  145887.0  1.748902 -0.989431  0.551572  1.539388 -0.982681  1.699766
# 253772  156414.0 -1.244621 -0.076079 -1.178757  0.266465  4.208991  3.038824
# 65622    51674.0 -1.928219  2.462479  0.456899 -0.355525  0.268436  0.654057
# 71288    54241.0  1.215496 -0.015518 -1.205686 -0.043102  2.165224  3.335896
# 241558  151077.0  0.109500  1.079375 -0.206070 -0.449092  0.762131 -0.999716
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
Y
# Out:
# 229347    0
# 253772    0
# 65622     0
# 71288     0
# 241558    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %% [markdown]
# ### Split the data into training data and testing data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2, random_state =2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %% [markdown]
# ## Model Training
# ### 1. Logistic Regression

# %%
model = LogisticRegression()

# %%
 #training the logistic regression model with training data
model.fit(X_train, Y_train)
# Out:
# C:\Users\HP-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# ##### Accuracy Score on training data

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on training data:',training_data_accuracy)
# Out:
# Accuracy on training data: 0.963151207115629

# %% [markdown]
# ##### Accuracy on test data

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('logistic regression Accuracy:',test_data_accuracy)
# Out:
# logistic regression Accuracy: 0.934010152284264

# %% [markdown]
# ##### Confusion Matrix - logistic Regression

# %%
from sklearn.metrics import ConfusionMatrixDisplay
confusion_matrix_lr = confusion_matrix(Y_test, X_test_prediction.round())
print("Confusion Matrix - Logistic Regression")
print(confusion_matrix_lr)
disp = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix_lr)
disp.plot()
plt.show()
# Out:
# Confusion Matrix - Logistic Regression
# [[90  5]
#  [ 8 94]]

# %% [markdown]
# ##### Evaluation of Logistic regression

# %%
print("Evaluation of Logistic regression Model")
print()
accuracy_lr = accuracy_score(Y_test, X_test_prediction.round())
precision_lr = precision_score(Y_test, X_test_prediction.round())
recall_lr = recall_score(Y_test, X_test_prediction.round())
f1score_lr = f1_score(Y_test, X_test_prediction.round())
print(f"Accuracy: {accuracy_lr}")
print(f"Precision: {precision_lr}")
print(f"Recall: {recall_lr}")
print(f"F1_score: {f1score_lr}")
# Out:
# Evaluation of Logistic regression Model
#
# Accuracy: 0.934010152284264
# Precision: 0.9494949494949495
# Recall: 0.9215686274509803
# F1_score: 0.9353233830845771

# %% [markdown]
# ### 2. Random Forest

# %%
#random forest classifier
from sklearn.ensemble import RandomForestClassifier
random_forest = RandomForestClassifier(n_estimators = 100)
random_forest.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %%
pred_rf = random_forest.predict(X_test)
rf_accuracy = accuracy_score(pred_rf, Y_test)
print("Random forest Accuracy",rf_accuracy)
# Out:
# Random forest Accuracy 0.9289340101522843

# %% [markdown]
# ##### Confusion Matrix - Random Forest

# %%
confusion_matrix_rf = confusion_matrix(Y_test, pred_rf.round())
print("Confusion Matrix - Random Forest")
print(confusion_matrix_rf)
disp = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix_rf)
disp.plot()
plt.show()
# Out:
# Confusion Matrix - Random Forest
# [[91  4]
#  [10 92]]

# %% [markdown]
# ##### Evaluation of Random Forest

# %%
print("Evaluation of Random Forest Model")
print()
accuracy_rf = accuracy_score(Y_test, pred_rf.round())
precision_rf = precision_score(Y_test, pred_rf.round())
recall_rf = recall_score(Y_test, pred_rf.round())
f1score_rf = f1_score(Y_test, pred_rf.round())
print(f"Accuracy: {accuracy_rf}")
print(f"Precision: {precision_rf}")
print(f"Recall: {recall_rf}")
print(f"F1_score: {f1score_rf}")
# Out:
# Evaluation of Random Forest Model
#
# Accuracy: 0.9289340101522843
# Precision: 0.9583333333333334
# Recall: 0.9019607843137255
# F1_score: 0.9292929292929293

# %%
print("Accuracy of logistic regression :",accuracy_lr)
print("Accuracy of Random Forest :",accuracy_rf)
# Out:
# Accuracy of logistic regression : 0.934010152284264
# Accuracy of Random Forest : 0.9289340101522843

# %% [markdown]
# ### 3. KNN

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier
# Initialize the model with k=5
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier()

# %%
pred_knn = knn.predict(X_test)
knn_accuracy = accuracy_score(pred_knn, Y_test)
print("KNN Accuracy",knn_accuracy)
# Out:
# KNN Accuracy 0.6294416243654822

# %% [markdown]
# ##### Confusion Matrix - KNN

# %%
confusion_matrix_knn = confusion_matrix(Y_test, pred_knn.round())
print("Confusion Matrix - KNN")
print(confusion_matrix_knn)
disp = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix_knn)
disp.plot()
plt.show()
# Out:
# Confusion Matrix - KNN
# [[64 31]
#  [42 60]]

# %% [markdown]
# ##### Evaluation of KNN

# %%
print("Evaluation of KNN Model")
print()
accuracy_knn = accuracy_score(Y_test, pred_knn.round())
precision_knn = precision_score(Y_test, pred_knn.round())
recall_knn = recall_score(Y_test, pred_knn.round())
f1score_knn = f1_score(Y_test, pred_knn.round())
print(f"Accuracy: {accuracy_knn}")
print(f"Precision: {precision_knn}")
print(f"Recall: {recall_knn}")
print(f"F1_score: {f1score_knn}")
# Out:
# Evaluation of KNN Model
#
# Accuracy: 0.6294416243654822
# Precision: 0.6593406593406593
# Recall: 0.5882352941176471
# F1_score: 0.6217616580310881

# %% [markdown]
# ### 4. SVM

# %%
#SVM
from sklearn.svm import SVC
# instantiate an object of class SVC()
# note that we are using cost C=1
svm = SVC(C=1)
svm.fit(X_train, Y_train)
# Out:
# SVC()

# %%
pred_svm = svm.predict(X_test)
svm_accuracy = accuracy_score(pred_svm, Y_test)
print("SVM Accuracy",svm_accuracy)
# Out:
# SVM Accuracy 0.4873096446700508

# %% [markdown]
# ##### Confusion Matrix - SVM

# %%
confusion_matrix_svm = confusion_matrix(Y_test, pred_svm.round())
print("Confusion Matrix - SVM")
print(confusion_matrix_svm)
disp = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix_svm)
disp.plot()
plt.show()
# Out:
# Confusion Matrix - SVM
# [[44 51]
#  [50 52]]

# %% [markdown]
# ##### Evaluation of SVM

# %%
print("Evaluation of SVM Model")
print()
accuracy_svm = accuracy_score(Y_test, pred_svm.round())
precision_svm = precision_score(Y_test, pred_svm.round())
recall_svm = recall_score(Y_test, pred_svm.round())
f1score_svm = f1_score(Y_test, pred_svm.round())
print(f"Accuracy: {accuracy_svm}")
print(f"Precision: {precision_svm}")
print(f"Recall: {recall_svm}")
print(f"F1_score: {f1score_svm}")
# Out:
# Evaluation of SVM Model
#
# Accuracy: 0.4873096446700508
# Precision: 0.5048543689320388
# Recall: 0.5098039215686274
# F1_score: 0.5073170731707317

# %% [markdown]
# ## Conclusion
# ##### In conclusion, the main objective of this project was to find the most suited model in credit card fraud detection in terms of the machine learning techniques chosen for the project,and it was met by building the four models and finding the accuracies of them all, the best model in terms of accuracies is logistic Regression which scored 93.3%. I believe that using the model will help in decreasing theamount of credit card fraud and increase the customers satisfaction as it will provide them with better experience in addition to feeling secure.
